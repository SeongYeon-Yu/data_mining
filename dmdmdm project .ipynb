# %%
import csv
import pandas as pd

# %%
 import matplotlib.pyplot as plt

# %%
import pandas as pd

df = pd.read_table(   'report.txt',sep="\t")
print(df)
# Out:
#             기간  자치구     동   구분          계     0~4세     5~9세   10~14세   15~19세  \
# 0     2020.2/4   합계    합계    계  9,985,652  292,868  367,054  374,594  435,678
# 1     2020.2/4   합계    합계  한국인  9,720,846  285,920  360,318  370,357  430,020
# 2     2020.2/4   합계    합계  외국인    264,806    6,948    6,736    4,237    5,658
# 3     2020.2/4  종로구    소계    계    160,520    3,468    4,717    5,202    6,716
# 4     2020.2/4  종로구    소계  한국인    150,383    3,346    4,550    5,091    6,218
# ...        ...  ...   ...  ...        ...      ...      ...      ...      ...
# 1348  2020.2/4  강동구  천호2동  한국인     34,853      984      874      835    1,100
# 1349  2020.2/4  강동구  천호2동  외국인        789       30       32       14        9
# 1350  2020.2/4  강동구    길동    계     46,950    1,244    1,431    1,367    1,794
# 1351  2020.2/4  강동구    길동  한국인     46,619    1,235    1,421    1,360    1,791
# 1352  2020.2/4  강동구    길동  외국인        331        9       10        7        3
#
# ...

# %%
import pandas as pd
df = pd.read_csv('report.txt',sep="\t")
df
# Out:
#             기간  자치구     동   구분          계     0~4세     5~9세   10~14세   15~19세  \
# 0     2020.2/4   합계    합계    계  9,985,652  292,868  367,054  374,594  435,678
# 1     2020.2/4   합계    합계  한국인  9,720,846  285,920  360,318  370,357  430,020
# 2     2020.2/4   합계    합계  외국인    264,806    6,948    6,736    4,237    5,658
# 3     2020.2/4  종로구    소계    계    160,520    3,468    4,717    5,202    6,716
# 4     2020.2/4  종로구    소계  한국인    150,383    3,346    4,550    5,091    6,218
# ...        ...  ...   ...  ...        ...      ...      ...      ...      ...
# 1348  2020.2/4  강동구  천호2동  한국인     34,853      984      874      835    1,100
# 1349  2020.2/4  강동구  천호2동  외국인        789       30       32       14        9
# 1350  2020.2/4  강동구    길동    계     46,950    1,244    1,431    1,367    1,794
# 1351  2020.2/4  강동구    길동  한국인     46,619    1,235    1,421    1,360    1,791
# 1352  2020.2/4  강동구    길동  외국인        331        9       10        7        3
#
# ...

# %%
plt.plot(df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-fbcb7f9f3ed2> in <module>
# ----> 1 plt.plot(df)
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2759 @docstring.copy(Axes.plot)
#    2760 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2761     return gca().plot(
#    2762         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
#    2763         is not None else {}), **kwargs)
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1645         """
#    1646         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1647         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1648         for line in lines:
#    1649             self.add_line(line)
#
# ...
